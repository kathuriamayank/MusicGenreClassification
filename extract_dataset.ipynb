# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import librosa
# %matplotlib inline

# %%
# Beat tracking example
import librosa
import librosa.display

y, sr = librosa.load("/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/blues/blues.00000.au")
#y :audio time series
#sr : sampling rate
librosa.display.waveplot(y,sr)

# %%
#MFCC
M=librosa.feature.mfcc(y,sr)
print (type(M))
M.shape
# Out:
# <type 'numpy.ndarray'>
# (20, 1293)

# %%
librosa.display.specshow(M,x_axis="time")
plt.colorbar()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %%
import os
def feature(path,label):
    features=[]
    labels=[]
    for ix in os.listdir(path):
        y,sr=librosa.load(path+ix)
        M=librosa.feature.mfcc(y,sr)
        features.append(M)
        labels.append(label)
        #print (M)
    return features,labels

path_2="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/classical/"
path_1="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/blues/"

path_3="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/country/"
path_4="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/disco/"
path_5="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/hiphop/"
path_6="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/jazz/"
path_7="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/metal/"
path_8="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/pop/"
path_9="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/reggae/"
path_10="/home/mayank/Desktop/all/MachineLearning/MusicGenreClassification/genres/rock/"
labels_1=[]
features_3=[]
features_1=[]
labels_2=[]
features_2=[]
labels_3=[]

labels_4=[]
features_4=[]
labels_5=[]
features_5=[]
labels_6=[]
features_6=[]
labels_7=[]
features_7=[]
labels_8=[]
features_8=[]
labels_9=[]
features_9=[]
labels_10=[]
features_10=[]
features_3,labels_3=feature(path_3,3)
features_1,labels_1=feature(path_1,1)


features_2,labels_2=feature(path_2,2)


features_4,labels_4=feature(path_4,4)
features_5,labels_5=feature(path_5,5)
features_6,labels_6=feature(path_6,6)
features_7,labels_7=feature(path_7,7)
features_8,labels_8=feature(path_8,8)
features_9,labels_9=feature(path_9,9)
features_10,labels_10=feature(path_10,10)

# %%
print(type(total))
labels=[]
features=[]
labels=labels_1+labels_2+labels_3+labels_4+labels_5+labels_6+labels_7+labels_8+labels_9+labels_10
features=features_1+features_2+features_3+features_4+features_5+features_6+features_7+features_8+features_9+features_10
features=np.matrix(features)
# Out:
# <type 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7e19c31787ed> in <module>()
#       4 labels=labels_1+labels_2+labels_3+labels_4+labels_5+labels_6+labels_7+labels_8+labels_9+labels_10
#       5 features=features_1+features_2+features_3+features_4+features_5+features_6+features_7+features_8+features_9+features_10
# ----> 6 features=np.matrix(features)
#
# /home/mayank/.local/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __new__(subtype, data, dtype, copy)
#     234
#     235         # now convert data to an array
# --> 236         arr = N.array(data, dtype=dtype, copy=copy)
#     237         ndim = arr.ndim
#     238         shape = arr.shape
#
# ValueError: could not broadcast input array from shape (20,1293) into shape (20)

# %%
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-cf359ac88e67> in <module>()
# ----> 1 features=np.array(features)
#       2 len(features)
#
# ValueError: could not broadcast input array from shape (20,1293) into shape (20)
